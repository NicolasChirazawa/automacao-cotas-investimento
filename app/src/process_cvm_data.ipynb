# %%
# Trazer as opções de configuração

import json

with open('../options.json', 'r') as file:
    data = json.load(file)
file.close()

# %%
# Recolhe e filtra os investimentos

import os
import pandas

data_dir = os.path.abspath('../archives/archives-csv/')

list_investments = pandas.read_csv(os.path.join(data_dir, 'teste.csv'), sep=';')
choosed_investments = data["INVESTMENTS"]["CNPJ"]

filtered_data = list_investments.query('CNPJ_FUNDO_CLASSE in @list_investments')
display(filtered_data)
# Out:
#      TP_FUNDO_CLASSE   CNPJ_FUNDO_CLASSE ID_SUBCLASSE   DT_COMPTC  \
# 0      CLASSES - FIF  00.017.024/0001-53          NaN  2026-01-02
# 1      CLASSES - FIF  00.017.024/0001-53          NaN  2026-01-05
# 2      CLASSES - FIF  00.017.024/0001-53          NaN  2026-01-06
# 3      CLASSES - FIF  00.017.024/0001-53          NaN  2026-01-07
# 4      CLASSES - FIF  00.017.024/0001-53          NaN  2026-01-08
# 5      CLASSES - FIF  00.017.024/0001-53          NaN  2026-01-09
# 6      CLASSES - FIF  00.017.024/0001-53          NaN  2026-01-12
# 7      CLASSES - FIF  00.017.024/0001-53          NaN  2026-01-13
# 8      CLASSES - FIF  00.017.024/0001-53          NaN  2026-01-14
# 9      CLASSES - FIF  00.017.024/0001-53          NaN  2026-01-15
# 10     CLASSES - FIF  00.017.024/0001-53          NaN  2026-01-16
# 11     CLASSES - FIF  00.017.024/0001-53          NaN  2026-01-19
# 12     CLASSES - FIF  00.017.024/0001-53          NaN  2026-01-20
# ...
